# %%
from satellite_analysis.graphs import massrelation as massrelation
from satellite_analysis.massrelations import stellarmass_relations
import yt
import glob
import numpy as np
import matplotlib.pyplot as plt


#first we define the plotting function that will be used at the end

def centralandsatellitegalaxypapercomparisons(gas_mass_central, gas_ratio_central, gas_mass_satellite,
                                              gas_ratio_satellite, central_all_mass_mvir, satellite_all_mass_mvir,
                                              output_dir, a, x, y1, y2):
    plt.figure(1, figsize=(20,10))
    plt.subplot(121)
    plt.title('Scale Factor %s' % str(a/1000))
    plt.xlabel('Halo Mass (Darkmatter + Stars + Gas @ Rvir)')
    plt.ylabel('Gas Mass / Halo Mass')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(10**(7.8), 10**(14))
    #plt.ylim(0.0, 0.10)
    plt.plot(x, y1)
    plt.scatter(central_all_mass_mvir, gas_ratio_central, s = 1)
    plt.scatter(satellite_all_mass_mvir, gas_ratio_satellite, s = 1, c = 'r')
    plt.legend(('Host Galaxies', 'Satellite Galaxies'))
    
    plt.subplot(122)
    plt.xlabel('Halo Mass')
    plt.ylabel('Gas Mass')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(10**(7.8), 10**(14))
    plt.ylim(10**(-2), 10**(14))
    plt.plot(x, y2)
    plt.scatter(central_all_mass_mvir, gas_mass_central, s = 1)
    plt.scatter(satellite_all_mass_mvir, gas_mass_satellite, s = 1, c = 'r')
    plt.savefig('%s/gasmassratio%s.png' % (output_dir, str(a)))
    plt.close()


#first find all of the halomass catalogs

#add argparse and make the out_dir if it doesnt exits
output_dir = '/Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/gasratio'
halomass_dirs = glob.glob('/Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA*')


#now, find the earliest and latest snapshots for each catalog
earliest_snap = []
latest_snap = []
for directory in halomass_dirs:
    all_snaps = glob.glob('%s/*.ascii' % directory)
    all_snaps.sort()
    earliest_snap.append(all_snaps[0])
    latest_snap.append(all_snaps[-1])

earliest_snap = earliest_snap[0][-9:-6]
latest_snap = latest_snap[-1][-9:-6]

#now make the list of all possible snapshots from the earlies and latest snap
a_list = [int(earliest_snap) + 10*x for x in range((int(latest_snap) - int(earliest_snap))//10 + 1)]

#now now I set up a nested loop to iterate over each a in my a_list in each of my VELA_dir halomass folder
for a in a_list:
    print('Generating dataset for a: %s' % a)
    
    central_ids, satellite_ids = [], []
    
    gas_mass_central, gas_mass_satellite = [], []
    
    gas_ratio_central, gas_ratio_satellite = [], []
    
    central_all_mass_mvir, satellite_all_mass_mvir = [], []
    
    for halomass_dir in halomass_dirs:
        print('Trying file: %s/halomass%s.ascii' % (halomass_dir, a))
        try:
            readfile = open('%s/halomass%s.ascii' % (halomass_dir, a))
            lines = readfile.readlines()
            halomass_lines = []
            for line in lines:
                halomass_lines.append(line.split())
            del halomass_lines[0]
            for data_lists in halomass_lines:
                #filter out the satellites (pid =/= -1) from the central galaxies they orbit (pid = -1)
                if float(data_lists[1]) == -1:
                    central_ids.append(float(data_lists[0]))
                    #need the Mvir for the centrals and the Mpeak for the satellites
                    
                    gas_mass_central.append(float(data_lists[8]))
                    
                    #Mvir = darkmatter + stars + gas @ rvir
                    Mvir = float(data_lists[2]) + float(data_lists[7]) + float(data_lists[8])
                    central_all_mass_mvir.append(Mvir)
                    
                    gas_ratio_central.append(float(data_lists[8]) / Mvir)
                    
                else:
                    satellite_ids.append(float(data_lists[0]))
                    #need the Mvir for the centrals and the Mpeak for the satellites
                    
                    gas_mass_satellite.append(float(data_lists[8]))
                    
                    Mpeak = float(data_lists[3]) + float(data_lists[7]) + float(data_lists[8])
                    satellite_all_mass_mvir.append(Mpeak)
                    
                    gas_ratio_satellite.append(float(data_lists[8]) / Mpeak)
                    
            readfile.close()
        except FileNotFoundError:
            print('No file: %s/halomass%s.ascii' % (halomass_dir, a))
            
    x = np.linspace(10**7.8, 10**14, 3000)
    y1 = [.16] * 3000
    y2 = [q*.16 for q in x]
    centralandsatellitegalaxypapercomparisons(gas_mass_central, gas_ratio_central, gas_mass_satellite,
                                              gas_ratio_satellite, central_all_mass_mvir, satellite_all_mass_mvir,
                                              output_dir, a, x, y1, y2)
# Out:
# Generating dataset for a: 100
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass100.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass100.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass100.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass100.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass100.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass100.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass100.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass100.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass100.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass100.ascii
# Generating dataset for a: 110
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass110.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass110.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass110.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass110.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass110.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass110.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass110.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass110.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass110.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass110.ascii
# Generating dataset for a: 120
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass120.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass120.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass120.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass120.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass120.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass120.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass120.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass120.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass120.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass120.ascii
# Generating dataset for a: 130
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass130.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass130.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass130.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass130.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass130.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass130.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass130.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass130.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass130.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass130.ascii
# Generating dataset for a: 140
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass140.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass140.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass140.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass140.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass140.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass140.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass140.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass140.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass140.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass140.ascii
# Generating dataset for a: 150
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass150.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass150.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass150.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass150.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass150.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass150.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass150.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass150.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass150.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass150.ascii
# Generating dataset for a: 160
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass160.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass160.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass160.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass160.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass160.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass160.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass160.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass160.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass160.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass160.ascii
# Generating dataset for a: 170
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass170.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass170.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass170.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass170.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass170.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass170.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass170.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass170.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass170.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass170.ascii
# Generating dataset for a: 180
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass180.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass180.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass180.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass180.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass180.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass180.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass180.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass180.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass180.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass180.ascii
# Generating dataset for a: 190
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass190.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass190.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass190.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass190.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass190.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass190.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass190.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass190.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass190.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass190.ascii
# Generating dataset for a: 200
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass200.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass200.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass200.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass200.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass200.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass200.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass200.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass200.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass200.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass200.ascii
# Generating dataset for a: 210
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass210.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass210.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass210.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass210.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass210.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass210.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass210.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass210.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass210.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass210.ascii
# Generating dataset for a: 220
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass220.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass220.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass220.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass220.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass220.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass220.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass220.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass220.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass220.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass220.ascii
# Generating dataset for a: 230
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass230.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass230.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass230.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass230.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass230.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass230.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass230.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass230.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass230.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass230.ascii
# Generating dataset for a: 240
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass240.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass240.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass240.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass240.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass240.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass240.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass240.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass240.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass240.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass240.ascii
# Generating dataset for a: 250
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass250.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass250.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass250.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass250.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass250.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass250.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass250.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass250.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass250.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass250.ascii
# Generating dataset for a: 260
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass260.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass260.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass260.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass260.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass260.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass260.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass260.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass260.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass260.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass260.ascii
# Generating dataset for a: 270
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass270.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass270.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass270.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass270.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass270.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass270.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass270.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass270.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass270.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass270.ascii
# Generating dataset for a: 280
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass280.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass280.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass280.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass280.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass280.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass280.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass280.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass280.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass280.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass280.ascii
# Generating dataset for a: 290
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass290.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass290.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass290.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass290.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass290.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass290.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass290.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass290.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass290.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass290.ascii
# Generating dataset for a: 300
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass300.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass300.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass300.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass300.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass300.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass300.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass300.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass300.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass300.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass300.ascii
# Generating dataset for a: 310
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass310.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass310.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass310.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass310.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass310.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass310.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halomass310.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA13/halomass310.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA14/halomass310.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA15/halomass310.ascii
# Generating dataset for a: 320
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA06/halomass320.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA07/halomass320.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA08/halomass320.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA09/halomass320.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA10/halomass320.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA11/halomass320.ascii
# Trying file: /Users/user1/documents/GEN6/rockstarcomoving001/stellarmassrelation/VELA12/halom