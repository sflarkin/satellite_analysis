# %%
from satellite_analysis.graphs import massrelation as massrelation
import yt
import glob

#first find all of the halomass catalogs
halomass_dirs = glob.glob('/Users/user1/documents/stellarmassanalysis/VELA*')

#now, find the earliest and latest snapshots for each catalog
earliest_snap = []
latest_snap = []
for directory in halomass_dirs:
    all_snaps = glob.glob('%s/*.ascii' % directory)
    all_snaps.sort()
    earliest_snap.append(all_snaps[0])
    latest_snap.append(all_snaps[-1])

earliest_snap = earliest_snap[0][-9:-6]
latest_snap = latest_snap[-1][-9:-6]

#now make the list of all possible snapshots from the earlies and latest snap
a_list = [int(earliest_snap) + 10*x for x in range((int(latest_snap) - int(earliest_snap))//10 + 1)]

#now now I set up a nested loop to iterate over each a in my a_list in each of my VELA_dir halomass folder
for a in a_list:
    stellarmass = []
    darkmattermass = []
    massratio = []
    for halomass_dir in halomass_dirs:
        try:
            readfile = open('%s/halomass%s.ascii' % (halomass_dir, a))
            lines = readfile.readlines()
            halomass_lines = []
            for line in lines:
                halomass_lines.append(line.split())
            del halomass_lines[0]
            for data_lists in halomass_lines:
                stellarmass.append(data_lists[1])
                darkmattermass.append(data_lists[2])
                massratio.append(data_lists[3])
            readfile.close()
        except FileNotFoundError:
            print('no file for this snap')
        
    #now use the extracted info from the current a to graph the relationships desired
    massrelation.massrelation(stellarmass, darkmattermass, massratio, halomass_dir, a)
# Out:
# Traceback (most recent call last):
#
#   File "/Users/user1/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-f5756576464e>", line 1, in <module>
#     from satellite_analysis.graphs import massrelation as massrelation
#
#   File "/Users/user1/anaconda3/lib/python3.6/site-packages/satellite_analysis/graphs/massrelation.py", line 16
#     plt.scatter(darkmattermass, stellarmass, s = .1)
#       ^
# SyntaxError: invalid syntax

# %%
print(darkmattermass)
# Out:
# ['158742888.35290232', '379131804.8560517', '128472883.97317764', '218642570.09662673', '833589351.3801104', '761872725.6189165', '252347055.7425125', '195940066.81183317', '1670089280.1044252', '338150875.84965503', '965496716.6194491', '603420895.0004348', '356021820.7430695', '225453321.08206484', '172364390.32377842', '462025047.61899', '348105050.36683375', '318650007.64348626', '412428809.6737487', '353576935.7739379', '765307206.8850777', '3088297196.841411', '222077051.3627878', '356487513.11814225', '609416684.3294955', '273245001.0738994', '277319809.35578537', '721299277.4407088', '2685938984.7786093', '154900926.25855264', '259157806.72795048', '280463232.887526', '5876630292.5891285', '175915294.68370762', '295831081.26492465', '158218984.43094552', '428378773.5199883', '182376776.38784117', '285585849.0133255', '203740414.09430078', '389609883.2951871', '3866294520.9472203', '143025770.6941991', '163516235.19739735', '240762957.9125794', '293560830.93644536', '