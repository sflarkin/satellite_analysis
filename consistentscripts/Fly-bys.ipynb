# %%
from satellite_analysis.catalogreaders import consistentcatalogreader as consistent

input_dir = '/Users/user1/documents/GEN3/rockstar_moresnaps/VELA07/hlists'

consistent.consistent_catalog_reader(input_dir)
# Out:
# Consistent File Indices: ['099', '100', '102', '104', '107', '110', '112', '114', '117', '120', '122', '125', '127', '129', '130', '132', '134', '137', '139', '140', '142', '145', '147', '150', '152', '154', '157', '159', '160', '162', '164', '167', '170', '172', '174', '177', '180', '182', '184', '187', '190', '192', '194', '197', '199', '200', '202', '205', '207', '210', '212', '214', '217', '220', '222', '224', '227', '230', '232', '234', '237', '239', '240', '242', '244', '247', '249', '250', '252', '255', '257', '259', '260', '262', '264', '267', '269', '270', '272', '275', '277', '280', '282', '285', '287', '289', '290', '292', '295', '297', '300', '302', '305', '307', '310', '312', '314', '317', '319', '320', '322', '324', '327', '329', '330', '332', '335', '337', '339', '340', '342', '344', '347', '349', '350', '352', '355', '357', '360', '362', '364', '367', '370', '372', '374', '377', '380', '382', '384', '387', '390', '392', '394', '397', '400', '402', '404', '407', '410',
# ...

# %%
storage = []

for halo in consistent.halo_data_sorted[181]:
    storage.append(halo[2])
print(storage)
# Out:
# ['0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.53032', '0.5303
# ...
