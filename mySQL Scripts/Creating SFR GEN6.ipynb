# %%
import glob
import mysql.connector

from mysql.connector import (connection)

#now we create the table in the database we want to add

mydb = connection.MySQLConnection(user='root', password='password',
                                 host='127.0.0.1', database='VELA_GEN6')

#print(mydb)

cursor = mydb.cursor()

cursor.execute("CREATE TABLE SFRandcontamination(VELA_number CHAR(2), scale_factor float(53), Halo_Id INT(255), Rvir float(53), Mvir float(53), stars0_SFR_010Rvir float(53), stars1_SFR_010Rvir float(53), stars2_SFR_010Rvir float(53), stars3_SFR_010Rvir float(53), stars4_SFR_010Rvir float(53), stars0_SSFR_010Rvir float(53), stars1_SSFR_010Rvir float(53), stars2_SSFR_010Rvir float(53), stars3_SSFR_010Rvir float(53), stars4_SSFR_010Rvir float(53), stars0_SFR_015Rvir float(53), stars1_SFR_015Rvir float(53), stars2_SFR_015Rvir float(53), stars3_SFR_015Rvir float(53), stars4_SFR_015Rvir float(53), stars0_SSFR_01Rvir float(53), stars1_SSFR_015Rvir float(53), stars2_SSFR_015Rvir float(53), stars3_SSFR_015Rvir float(53), stars4_SSFR_015Rvir float(53), stars0_SFR_020Rvir float(53), stars1_SFR_020Rvir float(53), stars2_SFR_020Rvir float(53), stars3_SFR_020Rvir float(53), stars4_SFR_020Rvir float(53), stars0_SSFR_020Rvir float(53), stars1_SSFR_020Rvir float(53), stars2_SSFR_020Rvir float(53), stars3_SSFR_020Rvir float(53), stars4_SSFR_020Rvir float(53), DM_Contamination_1Rvir_Mvir float(53), DM_Contamination_1Rvir_MassFraction float(53), DM_Contamination_1Rvir_Number_Particles INT(255), DM_Contamination_1Rvir_Number_Particles_Fraction float(53), DM_Contamination_LargerParticlesPresent_Bool bit, DM_Contamination_010Rvir_Number_Particles float(53), 60Myr_SFR_010Rvir float(53), 60Myr_SFR_015Rvir float(53), 60Myr_SFR_020Rvir float(53), 60Myr_SSFR_010Rvir float(53), 60Myr_SSFR_015Rvir float(53), 60Myr_SSFR_020Rvir float(53), 100Myr_SFR_010Rvir float(53), 100Myr_SFR_015Rvir float(53), 100Myr_SFR_020Rvir float(53), 100Myr_SSFR_010Rvir float(53), 100Myr_SSFR_015Rvir float(53), 100Myr_SSFR_020Rvir float(53), Tacchella_5Myr_SFR_010_AVG float(53), Tacchella_5Myr_SFR_010_MED float(53), Tacchella_5Myr_SSFR_010_AVG float(53), Tacchella_5Myr_SSFR_010_MED float(53), Tacchella_5Myr_SFR_015_AVG float(53), Tacchella_5Myr_SFR_015_MED float(53), Tacchella_5Myr_SSFR_015_AVG float(53), Tacchella_5Myr_SSFR_015_MED float(53), Tacchella_5Myr_SFR_020_AVG float(53), Tacchella_5Myr_SFR_020_MED float(53), Tacchella_5Myr_SSFR_020_AVG float(53), Tacchella_5Myr_SSFR_020_MED float(53), Tacchella_60Myr_SFR_010_AVG float(53), Tacchella_60Myr_SFR_010_MED float(53), Tacchella_60Myr_SSFR_010_AVG float(53), Tacchella_60Myr_SSFR_010_MED float(53), Tacchella_60Myr_SFR_015_AVG float(53), Tacchella_60Myr_SFR_015_MED float(53), Tacchella_60Myr_SSFR_015_AVG float(53), Tacchella_60Myr_SSFR_015_MED float(53), Tacchella_60Myr_SFR_020_AVG float(53), Tacchella_60Myr_SFR_020_MED float(53), Tacchella_60Myr_SSFR_020_AVG float(53), Tacchella_60Myr_SSFR_020_MED float(53), Tacchella_100Myr_SFR_010_AVG float(53), Tacchella_100Myr_SFR_010_MED float(53), Tacchella_100Myr_SSFR_010_AVG float(53), Tacchella_100Myr_SSFR_010_MED float(53), Tacchella_100Myr_SFR_015_AVG float(53), Tacchella_100Myr_SFR_015_MED float(53), Tacchella_100Myr_SSFR_015_AVG float(53), Tacchella_100Myr_SSFR_015_MED float(53), Tacchella_100Myr_SFR_020_AVG float(53), Tacchella_100Myr_SFR_020_MED float(53), Tacchella_100Myr_SSFR_020_AVG float(53), Tacchella_100Myr_SSFR_020_MED float(53))")



#now that the table is created, we read the data we want from each VELA sim file and load it into the table we just created

VELA_dirs = glob.glob('/Users/user1/documents/GEN6/rockstar001analysis/SFRandcontamination/VELA*')
VELA_dirs.sort()

for VELA_dir in VELA_dirs:
    VELA_number = VELA_dir[-2:]
    print(VELA_number)
    SFR_files = glob.glob('{}/SFRandcontamination[0-9][0-9][0-9].ascii'.format(VELA_dir))

    values_to_add = []

    for SFR_file in SFR_files:

        readfile = open(SFR_file)
        lines = readfile.readlines()

        count = 0
        current_scale = float(SFR_file[-9:-6])/1000
        for line in lines:
            #we want to skip the first line as it is just the headers
            if count == 0:
                count +=1
                continue

            current_line = line.split()
            current_line_sql = [VELA_number, str(current_scale)] + [str(x) for x in current_line]
            #print(current_line_sql[39])
            if current_line_sql[39] == 'True':
                #print("True")
                current_line_sql[39] = 1
            else:
                #print("False")
                current_line_sql[39] = 0
            
            #print(len(current_line_sql))
            values_to_add.append(tuple(current_line_sql))


        readfile.close()
        
    #now that we have the data we want to add, we add it to the Table
    
    #sql_add_command = 'INSERT INTO SFRandcontamination (VELA_number, scale_factor, rockstar_id, Rockstar_Mvir, Rockstar_Rvir, New_Rvir_Calculation, New_Rvir_error, Stellar_Mass_1Rvir, Gas_Mass_1Rvir, Darkmatter_Mass_1Rvir, Stellar_Mass_010Rvir, Gas_Mass_010Rvir, Stellar_Mass_015Rvir, Gas_Mass_015Rvir, Stellar_Mass_020Rvir, Gas_Mass_020Rvir, Stellar_Halfmass_Radius_010Rvir, Stellar_Halfmass_Radius_010Rvir_error, Stellar_Halfmass_Radius_015Rvir, Stellar_Halfmass_Radius_015Rvir_error, Stellar_Halfmass_Radius_020Rvir, Stellar_Halfmass_Radius_020Rvir_error) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'
    
    sql_add_command = 'INSERT INTO SFRandcontamination (VELA_number, scale_factor, Halo_Id, Rvir, Mvir, stars0_SFR_010Rvir, stars1_SFR_010Rvir, stars2_SFR_010Rvir, stars3_SFR_010Rvir, stars4_SFR_010Rvir, stars0_SSFR_010Rvir, stars1_SSFR_010Rvir, stars2_SSFR_010Rvir, stars3_SSFR_010Rvir, stars4_SSFR_010Rvir, stars0_SFR_015Rvir, stars1_SFR_015Rvir, stars2_SFR_015Rvir, stars3_SFR_015Rvir, stars4_SFR_015Rvir, stars0_SSFR_01Rvir, stars1_SSFR_015Rvir, stars2_SSFR_015Rvir, stars3_SSFR_015Rvir, stars4_SSFR_015Rvir, stars0_SFR_020Rvir, stars1_SFR_020Rvir, stars2_SFR_020Rvir, stars3_SFR_020Rvir, stars4_SFR_020Rvir, stars0_SSFR_020Rvir, stars1_SSFR_020Rvir, stars2_SSFR_020Rvir, stars3_SSFR_020Rvir, stars4_SSFR_020Rvir, DM_Contamination_1Rvir_Mvir, DM_Contamination_1Rvir_MassFraction, DM_Contamination_1Rvir_Number_Particles, DM_Contamination_1Rvir_Number_Particles_Fraction, DM_Contamination_LargerParticlesPresent_Bool, DM_Contamination_010Rvir_Number_Particles, 60Myr_SFR_010Rvir, 60Myr_SFR_015Rvir, 60Myr_SFR_020Rvir, 60Myr_SSFR_010Rvir, 60Myr_SSFR_015Rvir, 60Myr_SSFR_020Rvir, 100Myr_SFR_010Rvir, 100Myr_SFR_015Rvir, 100Myr_SFR_020Rvir, 100Myr_SSFR_010Rvir, 100Myr_SSFR_015Rvir, 100Myr_SSFR_020Rvir, Tacchella_5Myr_SFR_010_AVG, Tacchella_5Myr_SFR_010_MED, Tacchella_5Myr_SSFR_010_AVG, Tacchella_5Myr_SSFR_010_MED, Tacchella_5Myr_SFR_015_AVG, Tacchella_5Myr_SFR_015_MED, Tacchella_5Myr_SSFR_015_AVG, Tacchella_5Myr_SSFR_015_MED, Tacchella_5Myr_SFR_020_AVG, Tacchella_5Myr_SFR_020_MED, Tacchella_5Myr_SSFR_020_AVG, Tacchella_5Myr_SSFR_020_MED, Tacchella_60Myr_SFR_010_AVG, Tacchella_60Myr_SFR_010_MED, Tacchella_60Myr_SSFR_010_AVG, Tacchella_60Myr_SSFR_010_MED, Tacchella_60Myr_SFR_015_AVG, Tacchella_60Myr_SFR_015_MED, Tacchella_60Myr_SSFR_015_AVG, Tacchella_60Myr_SSFR_015_MED, Tacchella_60Myr_SFR_020_AVG, Tacchella_60Myr_SFR_020_MED, Tacchella_60Myr_SSFR_020_AVG, Tacchella_60Myr_SSFR_020_MED, Tacchella_100Myr_SFR_010_AVG, Tacchella_100Myr_SFR_010_MED, Tacchella_100Myr_SSFR_010_AVG, Tacchella_100Myr_SSFR_010_MED, Tacchella_100Myr_SFR_015_AVG, Tacchella_100Myr_SFR_015_MED, Tacchella_100Myr_SSFR_015_AVG, Tacchella_100Myr_SSFR_015_MED, Tacchella_100Myr_SFR_020_AVG, Tacchella_100Myr_SFR_020_MED, Tacchella_100Myr_SSFR_020_AVG, Tacchella_100Myr_SSFR_020_MED) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'


    
    cursor.executemany(sql_add_command, values_to_add)

    mydb.commit()

    print(cursor.rowcount, "was inserted.")
    
    #now we check that all the data matches and that no errors were made that need to be corrected
    
    
    #NEED TO CHANGE THIS TO ONLY GET ONES FROM VELA_Number
    cursor.execute("SELECT * FROM SFRandcontamination HAVING VELA_number = {}".format(VELA_number))

    myresult = cursor.fetchall()

    for x, y in zip(myresult, values_to_add):
        
        for x_sub, y_sub in zip(x,y):
            #this is for the rockstar_id, which are stored as a float with number.0 instead of number as they
            #are in the sql database, so to compare I have to make the ones from the ascii files ints
            if x_sub != int(float(y_sub)) and x_sub != float(y_sub) and x_sub != y_sub:
                    print(x_sub, y_sub)
                    print(type(x_sub), type(y_sub))
            
    print(VELA_number)
cursor.close()
mydb.close()
# Out:
# 01
# 64 was inserted.
# 01
# 02
# 76 was inserted.
# 02
# 03
# 47 was inserted.
# 03
# 04
# 56 was inserted.
# 04
# 05
# 47 was inserted.
# 05
# 06
# 292 was inserted.
# 06
# 07
# 182 was inserted.
# 07
# 08
# 227 was inserted.
# 08
# 09
# 208 was inserted.
# 09
# 10
# 139 was inserted.
# 10
# 11
# 115 was inserted.
# 11
# 12
# 75 was inserted.
# 12
# 13
# 106 was inserted.
# 13
# 14
# 110 was inserted.
# 14
# 15
# 43 was inserted.
# 15
# 16
# 143 was inserted.
# 16
# 17
# 125 was inserted.
# 17
# 18
# 61 was inserted.
# 18
# 19
# 121 was inserted.
# 19
# 20
# 95 was inserted.
# 20
# 21
# 104 was inserted.
# 21
# 22
# 85 was inserted.
# 22
# 23
# 80 was inserted.
# 23
# 24
# 98 was inserted.
# 24
# 25
# 64 was inserted.
# 25
# 26
# 52 was inserted.
# 26
# 27
# 50 was inserted.
# 27
# 28
# 48 was inserted.
# 28
# 29
# 119 was inserted.
# 29
# 30
# 98 was inserted.
# 30
# 31
# 79 was inserted.
# 31
# 32
# 107 was inserted.
# 32
# 33
# 137 was inserted.
# 33
# 34
# 158 was inserted.
# ...
